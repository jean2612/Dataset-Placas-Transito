# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5.git  # clone repo
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9363, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 9363 (delta 10), reused 0 (delta 0), pack-reused 9338
# Receiving objects: 100% (9363/9363), 9.79 MiB | 12.21 MiB/s, done.
# Resolving deltas: 100% (6501/6501), done.

# %%
pwd
# Out:
# '/content'

# %%
# %cd '/content/drive/MyDrive/TCC/yolov5'  # ir para diretório do drive onde yolo vai ficar, nesse caso, dentro da pasta "Outdoor"
# !pip install -qr /content/drive/MyDrive/TCC/yolov5/requirements.txt
# %cd /content/drive/MyDrive/TCC/yolov5
print('-------------------------------------------------------------------------')
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/TCC/yolov5 # ir para diretório do drive onde yolo vai ficar, nesse caso, dentro da pasta Outdoor'
# /content
#      |████████████████████████████████| 3.0 MB 8.7 MB/s
#      |████████████████████████████████| 636 kB 81.8 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# /content/drive/MyDrive/TCC/yolov5
# -------------------------------------------------------------------------
# CONTRIBUTING.md  export.py   models	       runs	       val.py
# data		 hubconf.py  __pycache__       train.py
# detect.py	 inference   README.md	       tutorial.ipynb
# Dockerfile	 LICENSE     requirements.txt  utils

# %%
import torch
from IPython.display import Image, clear_output # to display images
clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# %cd ..
# %cd /content/drive/MyDrive/TCC/yolov5/data
# !echo "train: ./../dataset/images/train" > dataset.yaml
# !echo "val: ./../dataset/images/val" >> dataset.yaml
# !echo "# number of classes" >> dataset.yaml
# !echo "nc: 3" >> dataset.yaml
# !echo "# class names" >> dataset.yaml
# !echo "names: ['regulamentacao', 'advertencia', 'indicacao']" >> dataset.yaml
# %cd ..
# Out:
# Setup complete. Using torch 1.9.0+cu102 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)
# /content/drive/My Drive/TCC
# /content/drive/MyDrive/TCC/yolov5/data
# /content/drive/My Drive/TCC/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 500 --data /content/drive/MyDrive/TCC/yolov5/data/dataset.yaml --cfg /content/drive/MyDrive/TCC/yolov5/models/yolov5x.yaml --weights ''
# Out:
# train: weights=, cfg=/content/drive/MyDrive/TCC/yolov5/models/yolov5x.yaml, data=/content/drive/MyDrive/TCC/yolov5/data/dataset.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=500, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (1/1), done.
# From https://github.com/ultralytics/yolov5
#    3beb871..27a4736  master     -> origin/master
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 500 --data /content/drive/MyDrive/TCC/yolov5/data/dataset.yaml --cfg /content/drive/MyDrive/TCC/yolov5/models/yolov5m.yaml --weights '' --resume

# %%
! python detect.py --source ./inference/images/ --weights ./runs/train/exp7/weights/best.pt --conf 0.8
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# video 1/1 (22747/27744) /content/drive/My Drive/TCC/yolov5/inference/images/BR-116, Jequié-BA _Rodovia ao extremo_.mp4: 384x640 Done. (0.028s)
# video 1/1 (22748/27744) /content/drive/My Drive/TCC/yolov5/inference/images/BR-116, Jequié-BA _Rodovia ao extremo_.mp4: 384x640 Done. (0.028s)
# video 1/1 (22749/27744) /content/drive/My Drive/TCC/yolov5/inference/images/BR-116, Jequié-BA _Rodovia ao extremo_.mp4: 384x640 Done. (0.028s)
# video 1/1 (22750/27744) /content/drive/My Drive/TCC/yolov5/inference/images/BR-116, Jequié-BA _Rodovia ao extremo_.mp4: 384x640 Done. (0.028s)
# video 1/1 (22751/27744) /content/drive/My Drive/TCC/yolov5/inference/images/BR-116, Jequié-BA _Rodovia ao extremo_.mp4: 384x640 Done. (0.028s)
# video 1/1 (22752/27744) /content/drive/My Drive/TCC/yolov5/inference/images/BR-116, Jequié-BA _Rodovia ao extremo_.mp4: 384x640 Done. (0.028s)
# ...

# %%
! python detect.py --source ./inference/images/teste/ --weights ./runs/train/exp3/weights/best.pt --conf 0.8
